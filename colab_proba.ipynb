# %% [markdown]
# <a href="https://colab.research.google.com/github/vencyko/Informacionni-tehnologii-7a-klas/blob/main/colab_proba.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print('Hello world')
# Out:
# Hello world
